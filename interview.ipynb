# %% [markdown]
# # Hello

# %% [markdown]
# My name is Andrew Webber. I'm a decent student and I would like to pitch for an A in my interview grading. Shoot for the moon and I might hit myself in the face

# %% [markdown]
# ### I learned that
# I like the Julia programming language. I had no prior experience with it (or even knew of its existence) before this class, but now it's my preferred language to code little software knickknacks in. \
# These were two small projects spawned out of my learning goals that I made to get comfortable with Julia

# %%
include("./lgprojects-verywellmade/blackjack.jl") # Didn't expect jupyter to have input support. What a neat surprise
# Out:
# Card drawn: 2 for player player
# Card drawn: 1 for player dealer
# Card drawn: 9 for player player
# Card drawn: 4 for player dealer
# Player cards: 2, 9 Total sum: 11
# Dealer cards: 1, 4 Total sum: 5
# Type 'hit' to draw another card or 'stand' to hold.
# stdin>  hit
# Card drawn: 3 for player player
# Player cards: 2, 9, 3 Total sum: 14
# Type 'hit' to draw another card or 'stand' to hold.
# stdin>  hit
# Card drawn: 5 for player player
# Player cards: 2, 9, 3, 5 Total sum: 19
# Type 'hit' to draw another card or 'stand' to hold.
# stdin>  stand
# Card drawn: 4 for player dealer
# Dealer cards: 1, 4, 4 Total sum: 9
# Card drawn: 6 for player dealer
# Dealer cards: 1, 4, 4, 6 Total sum: 15
# Card drawn: 1 for player dealer
# Dealer cards: 1, 4, 4, 6, 1 Total sum: 16
# Card drawn: 10 for player dealer
# Dealer cards: 1, 4, 4, 6, 1, 10 Total sum: 26
# You win
# Play again? (yes/no)
# stdin>  no

# %%
include("./lgprojects-verywellmade/gameoflife.jl");

# %%
runAndGenerateGIF(200)
# Out:
# [ Info: Saved animation to C:\Users\Andrew\Documents\Repositories\CSCI-3656-Interview-Read-Ahead\gameoflife.gif
# Plots.AnimatedGif("C:\\Users\\Andrew\\Documents\\Repositories\\CSCI-3656-Interview-Read-Ahead\\gameoflife.gif")

# %% [markdown]
# I also learned I hate python (and manimating) or maybe I just don't get it.
#
# I wanted to make a YouTube-esque tutorial video explaining rootfinding using Manim as a learning goal, but when I sat down and tried to use Manim I realized I wasn't cut out to create even two minutes of it. Here's what I have to show from that:

# %% [markdown]
# ![Image Test](./lgprojects-verywellmade/funny.gif)

# %% [markdown]
# ### What I'm solid on
# The theory we go over in this class I'm able to keep up with. I had a pretty good showing on the quizzes, so I'm confident in saying at least this much.
# ### Matrices scare me
# I'm not very good at linear algebra because I took my linear algebra class in a strange manner, so anything involving matrices or definitions around concepts related to matrices I had issue with. But I'm more comfortable with them now having had the chance to go over topics like QR factorization once again

# %% [markdown]
# ### Additional things
# My last learning goal project (my fourth) was me playing around with my group project proposal because we had initially chosen a different package to work with, but we have since pivoted to using my proposal because I had work on it done already, so my last learning goal became my group project. Here's the graph that I made that mimics the [Wikipedia example](https://en.wikipedia.org/wiki/Lotka%E2%80%93Volterra_equations#A_simple_example):\
# ![Ha](./lgprojects-verywellmade/awseome_plot.png)\
# I didn't keep up with my journal goal very well, but I tried to be as 'reflect-ful' as possible when I remembered to do it.\
# I did every optional exploration on the homeworks. \
# I responded to all my homework feedback over break. I also looked over my quiz feedback for the quizzes I could find and lamented my failure.
# ### Additional additional thing
# I didn't list this as a learning goal project because I didn't complete it and it was very recently put together, but I wanted to make a version of [The Powder Toy](https://github.com/The-Powder-Toy/The-Powder-Toy) with the heat differential equation implementation we went over in class. I didn't get very far in any of my implementations. I've figured out how to change the heat conductivity of an area, at least. \
# ![Proof](./lgprojects-verywellmade/heat_plate_fixed2.gif) \
# I stole your notebook and GeeksforGeeks implementation of finding a point in a triangle. The area inside of the triangle conducts heat 50x more than the area outside of it. I wanted to push it further, but I began reaching dubious territory, so I remained content with this. I need to figure out how to make it work if I wanted to simulate hundreds of thousands of particles at the same time to truly make The Powder Toy...

# %% [markdown]
# ### Thanks (irrelevant things)
# I liked this class and your anecdotes. One time you mentioned how you watch a German soap opera for language proficieny, and I think over this break I'll try it out to better my French. I have never watched any reality shows or soap operas or anything of similar genre, so I'm not sure what to expect.\
# I wrote this all before the group project presentation but I scheduled my interview for after that, so hopefully something disastrous doesn't happen between now and the interview.\
# Once again, thank you for reading this.
